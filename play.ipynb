# %%
# Change only this URL, then run all cells.
URL = "https://www.youtube.com/watch?v=KVHtuwVhULA"

OUTPUT_DIR = "youtube_subs"
WIDTH = 960
PREFERRED_LANGUAGE = "ko"
MODEL = "medium"
LANGUAGE = ""
TRANSLATE_TO = "ko"
DEVICE = "cuda"
COMPUTE_TYPE = "float16"
BEAM_SIZE = 5
PROMPT_HINT = ""

# %%
from IPython.display import display
from jupyter_video_helper import show_video_for_url

player = show_video_for_url(
    url=URL,
    root=OUTPUT_DIR,
    width=WIDTH,
    preferred_language=PREFERRED_LANGUAGE,
    model=MODEL,
    language=LANGUAGE,
    device=DEVICE,
    compute_type=COMPUTE_TYPE,
    beam_size=BEAM_SIZE,
    prompt_hint=PROMPT_HINT,
    translate_to=TRANSLATE_TO,
)

display(player)
# Out:
# Reusing saved subtitles for URL: https://www.youtube.com/watch?v=KVHtuwVhULA
# Video file      : /workspace/Deep-RL-Notes-master/youtube_subs/video/CS 285： Lecture 6, Part 2 [KVHtuwVhULA].mp4
# Subtitle file   : /workspace/Deep-RL-Notes-master/youtube_subs/CS 285 Lecture 6, Part 2.ko.vtt
# <div style="max-width:960px;">
#   <video controls width="960" style="max-width:100%; border-radius: 12px;">
#     <source src="youtube_subs/video/CS%20285%EF%BC%9A%20Lecture%206%2C%20Part%202%20%5BKVHtuwVhULA%5D.mp4" type="video/mp4">
#     <track src="youtube_subs/CS%20285%20Lecture%206%2C%20Part%202.ko.vtt" kind="subtitles" srclang="ko" label="Subtitle" default>
#     Your browser does not support embedded video playback.
#   </video>
# </div>
